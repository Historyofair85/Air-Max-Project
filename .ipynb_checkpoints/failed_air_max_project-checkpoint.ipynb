# %%
print('Air Max by YOU')
print('Lets get started...')

shopping_cart = []

air_max_by_you_model = input('Welcome to Air Max by You! Lets continue? Y/N')
#models = ['air max 1', 'air max 90', 'air max 180', 'air max 95', 'air max 97']

print("1. Air Max 1")
print("2. Air Max 90")
print("3. Air Max 180")
print("4. Air Max 95")
print("5. Air Max 97")

choice = input("Chose which Air Max to personalize: ")

if choice == "1":
    print("Air Max 1")
elif choice == "2":
    print("Air Max 90")
elif choice == "3":
    print("Air Max 180")
elif choice == "4":
    print('Air Max 95')
elif choice == "5":
    print('Air Max 97')
else:
    print("Invalid choice")
    

print("1. leather")
print("2. suede")
print("3. synthetic")
print("4. exotic + $100")

air_max_by_you_upper = input('What type of material would you like the Upper to be?')

if choice == "1":
    print("leather")
elif choice == "2":
    print("suede")
elif choice == "3":
    print("synthetic")
elif choice == "4": 
    print('exotic + $100')
else: 
    print("Invalid choice")
    
    
    
print("1. White")
print("2. Black")
print("3. Sail")
print("4. Speckled + $5")

air_max_by_you_midsole = input('What type of Midsole would you prefer?')

if choice == "1":
    print("White")
elif choice == "2":
    print("Black")
elif choice == "3":
    print("Sail")
elif choice == "4": 
    print('Speckled + $5')
else: 
    print("Invalid choice")
    
print("1. Clear")
print("2. Black")
print("3. Red Tint")
print("4. Volt Yellow + $10")

air_max_by_you_air_unit = input('What color Air Max unit would you prefer?')

if choice == "1":
    print("Clear")
elif choice == "2":
    print("Black")
elif choice == "3":
    print("Red Tint")
elif choice == "4": 
    print('Volt Yellow + $10')
else: 
    print("Invalid choice")
    
      
print("1. Solid Rubber")
print("2. Translucent")
print("3. Crepe")
print("4. Gum Sole + $10")

air_max_by_you_outsole = input('What type of outsole would you prefer?')

if choice == "1":
    print("Solid Rubber")
elif choice == "2":
    print("Translucent")
elif choice == "3":
    print("Crepe")
elif choice == "4": 
    print('Gum Sole + $10')
else: 
    print("Invalid choice")
    
    
def air_max_by_you(customer_name, model=True, upper=True, midsole=True, air_unit=True, outsole=True):
    total_price = 200
    message = f'Thank you {customer_name}. Here is your Air Max creation:\n'
    message += '1 Bespoke Air Max\n'
    if model:
        message += '\tChoice Model\n'
    if upper:
        message += '\tChoice Upper Material\n'
    if midsole:
        message += '\tChoice Midsole Option\n'
    if air_unit:
        message += '\tChoice Air Unit\n'
    if outsole:
        message += '\tChoice outsole\n'
    message += f'Total: ${total_price:.2f}'
    print(message)

    
air_max_by_you('Nikki')
# Out:
# Air Max by YOU
# Lets get started...
