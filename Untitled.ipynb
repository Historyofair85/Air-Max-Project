# %%
price = input('price')

if float(price) >=  2.99:
    print("Congrats its on sale")
else:
    print('it is not on sale')

# %%
height = input()
if float(height) <= 1:
    print('you cannot ride 1m')
elif float(height) >= 2:
    print('you cannot ride, over 2m')
else:
    print("you can ride")
# Out:
# 2
# you cannot ride, over 2m

# %%
18

# %%
loop = True
while loop:
    sneaker = input(' Nike')
    if sneaker == ('jordan', 'air', 'max', 'nike', 'dunk', 'low', 'high'):
        print(sneaker)
# Out:
#  Nikeair jordan
#  Nikeair max
#  Niketailwind

# %%
#Air Max for You
print('Air Max by YOU')
print('Lets get started...')

shopping_cart = []

air_max_by_you_model = input('Welcome to Air Max by You! Lets contine? Y/N')
models = ['air max 1', 'air max 90', 'air max 180', 'air max 95', 'air max 97']

print("1. Air Max 1")
print("2. Air Max 90")
print("3. Air Max 180")
print("4. Air Max 95")
print("5. Air Max 97")

choice = input("Enter your choice: ")

if choice == "1":
    print("Air Max 1")
elif choice == "2":
    print("Air Max 90")
elif choice == "3":
    print("Air Max 180")
elif choice == "4":
    print('Air Max 95')
elif choice == "5":
    print('Air Max 97')
else:
    print("Invalid choice")


air_max_by_you_upper = input('What type of material would you like the Upper to be?')
upper = ['leather', 'suede', 'synthetic', 'exotic']
print("1. leather")
print("2. suede")
print("3. synthetic")
print("4. exotic")

choice = input("Enter your choice")

if choice == "1":
    print('leather')

input 

air_max_by_you_midsole = input('Which Midsole would you like?')
air_max_by_you_air_unit = input('What color Air Max Unit would you prefer?')
air_max_by_you_outsole = input('What kind of outsole would you like?')


models = ['air max 1', 'air max 90', 'air max 180', 'air max 95', 'air max 97']

leather2 = ['smooth leather', 'tumbled leather', 'patent leather']
suede2 = ['cowhide', 'nubuck', 'pigskin', 'ultra']
synthetic2 = ['canvas', 'mesh', 'knit']
exotic2 = ['crocodile', 'python', 'ostrich']

midsole = ['white', 'black', 'sail', 'speckled']

air_unit = ['clear', 'black', 'red tint', 'volt yellow']
outsole = ['solid rubber', 'clear rubber', 'crepe', 'gumsole']
colors = ['black nior', 'white', 'sail', 'royal blue', 'sport red', 'flash pink', 'pecan brown', 'volt yellow']

def air_max_by_you(customer_name, model=True, upper=True, midsole=True, air_unit=True, outsole=True):
    total_price = 200
    message = f'Thank you {customer_name}. Here is your Air Max creation:\n'
    message += '1 Bespoke Air Max\n'
    if model:
        message += '\tmodel\n'
    if upper:
        message += '\tupper\n'
    if midsole:
        message += '\tmidsole\n'
    if air_unit:
        message += '\tair_unit\n'
    if outsole:
        message += '\toutsole\n'
    message += f'Total: ${total_price:.2f}'
    print(message)

    
air_max_by_you('Nikki')
# Out:
# Air Max by YOU
# Lets get started...
# Welcome to Air Max by You! Lets contine? Y/Ny
# 1. Air Max 1
# 2. Air Max 90
# 3. Air Max 180
# 4. Air Max 95
# 5. Air Max 97
# Enter your choice: 3
# Air Max 180

# %%
def air_max_by_you(customer_name, model=True, upper=True, midsole=True, air_unit=True, outsole=True):
    total_price = 200
    message = f'Thank you {customer_name}. Here is your Air Max creation:\n'
    message += '1 Bespoke Air Max\n'
    if model:
        message += '\tChoice Model\n'
    if upper:
        message += '\tChoice Upper Material\n'
    if midsole:
        message += '\tChoice Midsole Option\n'
    if air_unit:
        message += '\tChoice Air Unit\n'
    if outsole:
        message += '\tChoice outsole\n'
    message += f'Total: ${total_price:.2f}'
    print(message)

    
air_max_by_you('Nikki')
# Out:
# Thank you Nikki. Here is your Air Max creation:
# 1 Bespoke Air Max
# 	Choice Model
# 	Choice Upper Material
# 	Choice Midsole Option
# 	Choice Air Unit
# 	Choice outsole
# Total: $200.00

# %%
print('Air Max by YOU')
print('Lets get started...')

shopping_cart = []

air_max_by_you_model = input('Welcome to Air Max by You! Lets continue? Y/N')
#models = ['air max 1', 'air max 90', 'air max 180', 'air max 95', 'air max 97']

print("1. Air Max 1")
print("2. Air Max 90")
print("3. Air Max 180")
print("4. Air Max 95")
print("5. Air Max 97")

choice = input("Chose which Air Max to personalize: ")

if choice == "1":
    print("Air Max 1")
elif choice == "2":
    print("Air Max 90")
elif choice == "3":
    print("Air Max 180")
elif choice == "4":
    print('Air Max 95')
elif choice == "5":
    print('Air Max 97')
else:
    print("Invalid choice")
    

print("1. leather")
print("2. suede")
print("3. synthetic")
print("4. exotic + $100")

air_max_by_you_upper = input('What type of material would you like the Upper to be?')

if choice == "1":
    print("leather")
elif choice == "2":
    print("suede")
elif choice == "3":
    print("synthetic")
elif choice == "4": 
    print('exotic + $100')
else: 
    print("Invalid choice")
    
    
    
print("1. White")
print("2. Black")
print("3. Sail")
print("4. Speckled + $5")

air_max_by_you_midsole = input('What type of Midsole would you prefer?')

if choice == "1":
    print("White")
elif choice == "2":
    print("Black")
elif choice == "3":
    print("Sail")
elif choice == "4": 
    print('Speckled + $5')
else: 
    print("Invalid choice")
    
print("1. Clear")
print("2. Black")
print("3. Red Tint")
print("4. Volt Yellow + $10")

air_max_by_you_air_unit = input('What color Air Max unit would you prefer?')

if choice == "1":
    print("Clear")
elif choice == "2":
    print("Black")
elif choice == "3":
    print("Red Tint")
elif choice == "4": 
    print('Volt Yellow + $10')
else: 
    print("Invalid choice")
    
      
print("1. Solid Rubber")
print("2. Translucent")
print("3. Crepe")
print("4. Gum Sole + $10")

air_max_by_you_outsole = input('What type of outsole would you prefer?')

if choice == "1":
    print("Solid Rubber")
elif choice == "2":
    print("Translucent")
elif choice == "3":
    print("Crepe")
elif choice == "4": 
    print('Gum Sole + $10')
else: 
    print("Invalid choice")
    
    
def air_max_by_you(customer_name, model=True, upper=True, midsole=True, air_unit=True, outsole=True):
    total_price = 200
    message = f'Thank you {customer_name}. Here is your Air Max creation:\n'
    message += '1 Bespoke Air Max\n'
    if model:
        message += '\tChoice Model\n'
    if upper:
        message += '\tChoice Upper Material\n'
    if midsole:
        message += '\tChoice Midsole Option\n'
    if air_unit:
        message += '\tChoice Air Unit\n'
    if outsole:
        message += '\tChoice outsole\n'
    message += f'Total: ${total_price:.2f}'
    print(message)

    
air_max_by_you('Nikki')
# Out:
# Air Max by YOU
# Lets get started...
